# %%
import math

# %%
def NR(k):

    if k == 0:
        return 0
    elif k == 1:
        return 2
    else:
        return (math.exp(-0.5*NR(k-1)) - NR(k-1)**5 - NR(k-1) - math.sin(2*NR(k-1)) + 1)

# %%
values = [NR(n) for n in range(0,4)]

# %%
values
# Out:
# [0, 2, -31.87531806352063, 41254903.36742032]
